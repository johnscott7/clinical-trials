# %% [markdown]
# # 01 — Data Overview
# **ClinicalTrials.gov Dataset**
# *Author: John Seaton*
# *Last updated: 2025-12-08*
#
# ---
# ## 1. Scope & Role of This Notebook
#
# **Project context:** This notebook provides a high-level overview of the raw ClinicalTrials.gov dataset before any exploration or cleaning.
#
# **Goals:**
#
# This notebook establishes the following:
# - What files are present?
# - How large is the dataset?
# - What columns exist?
# - What are the basic types and missingness patterns?
# - Are there any initial structural anomalies?
#
# This notebook does not modify the data.

# %% [markdown]
# ## 2. Imports & Settings
# Load core libraries for data exploration below.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# %% [markdown]
# ## 3. Load Raw Data

# %%
df = pd.read_csv("../data/raw/ClinicalTrials/ctg-studies.csv")
df.shape
# Out:
# (530028, 22)

# %%
df.head()
# Out:
#     NCT Number                                        Study Title  \
# 0  NCT05299372              Telemonitoring in NIV MND (OptNIVent)
# 1  NCT01662895  High-Dose Deferoxamine in Intracerebral Hemorr...
# 2  NCT06047795  Endurance Training in Patients With Post-TB Lu...
# 3  NCT00414895  Absolute Myocardial Perfusion Measurement in t...
# 4  NCT05934695  Lymphedema Severity on Shoulder Joint Function...
#
#                                       Study URL Study Status  \
# 0  https://clinicaltrials.gov/study/NCT05299372      UNKNOWN
# 1  https://clinicaltrials.gov/study/NCT01662895   TERMINATED
# 2  https://clinicaltrials.gov/study/NCT06047795    COMPLETED
# 3  https://clinicaltrials.gov/study/NCT00414895    COMPLETED
# 4  https://clinicaltrials.gov/study/NCT05934695    COMPLETED
#
#                                           Conditions  \
# 0  Motor Neuron Disease, Amyotrophic Lateral Scle...
# 1                           Intracerebral Hemorrhage
# 2  Tuberculosis|Post-Tuberculous Pleural Fibrosis...
# 3                            Cardiac Transplantation
# 4                 Breast Cancer|Breast Cancer Female
#
#                                Interventions  \
# 0      OTHER: Telemonitoring via Careportal®
# 1     DRUG: Deferoxamine|DRUG: Normal saline
# 2         OTHER: Experimental|OTHER: Control
# 3                                        NaN
# 4  OTHER: Lymphedema severity stratification
#
#                             Primary Outcome Measures  \
# 0  Acceptability - Qualitative data through semi-...
# 1  Number of Subjects With Modified Rankin Scale ...
# 2  Functional capacity, Changes from baseline to ...
# 3                                                NaN
# 4  Shoulder joint mobility, shoulder flexion, abd...
#
#                           Secondary Outcome Measures  \
# 0  Patient Reported Outcome Measurement - Neurolo...
# 1  Number of Subjects With mRS Score 0-3, The pro...
# 2                                                NaN
# 3                                                NaN
# 4  Shoulder flexors strength, Maximal shoulder fl...
#
#                                              Sponsor  \
# 0  Liverpool University Hospitals NHS Foundation ...
# 1               Beth Israel Deaconess Medical Center
# 2                    Riphah International University
# 3          Insel Gruppe AG, University Hospital Bern
# 4                          Ahram Canadian University
#
#                                        Collaborators                 Age  \
# 0                                                NaN  ADULT, OLDER_ADULT
# 1  Medical University of South Carolina|National ...  ADULT, OLDER_ADULT
# 2                                                NaN               ADULT
# 3  Swiss National Science Foundation|Swiss Heart ...  ADULT, OLDER_ADULT
# 4                                                NaN  ADULT, OLDER_ADULT
#
#    Phases  Enrollment Funder Type      Study Type  \
# 0     NaN        15.0   OTHER_GOV  INTERVENTIONAL
# 1  PHASE2        42.0       OTHER  INTERVENTIONAL
# 2     NaN        36.0       OTHER  INTERVENTIONAL
# 3     NaN        90.0       OTHER   OBSERVATIONAL
# 4     NaN        75.0       OTHER   OBSERVATIONAL
#
#                                         Study Design  Start Date  \
# 0  Allocation: NA|Intervention Model: SINGLE_GROU...  2022-04-25
# 1  Allocation: RANDOMIZED|Intervention Model: PAR...  2013-03-18
# 2  Allocation: RANDOMIZED|Intervention Model: PAR...  2023-09-11
# 3          Observational Model: |Time Perspective: p     2006-12
# 4          Observational Model: |Time Perspective: p  2023-06-30
#
#   Primary Completion Date Completion Date First Posted  \
# 0              2022-10-31      2022-12-31   2022-03-29
# 1              2014-01-15      2018-05-10   2012-08-13
# 2              2024-06-30      2024-06-30   2023-09-21
# 3                 2008-12         2009-06   2006-12-22
# 4              2024-01-03      2024-01-03   2023-07-07
#
#                                            Locations Study Documents
# 0                                                NaN             NaN
# 1  St. Joseph's Hospital, Phoenix, Arizona, 85013...             NaN
# 2     Green Star NGO, Peshawar, KPK, 25000, Pakistan             NaN
# 3  University Hospital Inselspital, Bern, 3010, S...             NaN
# 4  Outpatient clinic of faculty of physical thera...             NaN

# %% [markdown]
# ## 4. Column Overview

# %%
df.columns.tolist()
# Out:
# ['NCT Number',
#  'Study Title',
#  'Study URL',
#  'Study Status',
#  'Conditions',
#  'Interventions',
#  'Primary Outcome Measures',
#  'Secondary Outcome Measures',
#  'Sponsor',
#  'Collaborators',
#  'Age',
#  'Phases',
#  'Enrollment',
#  'Funder Type',
#  'Study Type',
#  'Study Design',
#  'Start Date',
#  'Primary Completion Date',
#  'Completion Date',
#  'First Posted',
#  'Locations',
#  'Study Documents']

# %%
df.dtypes
# Out:
# NCT Number                     object
# Study Title                    object
# Study URL                      object
# Study Status                   object
# Conditions                     object
# Interventions                  object
# Primary Outcome Measures       object
# Secondary Outcome Measures     object
# Sponsor                        object
# Collaborators                  object
# Age                            object
# Phases                         object
# Enrollment                    float64
# Funder Type                    object
# Study Type                     object
# Study Design                   object
# Start Date                     object
# Primary Completion Date        object
# Completion Date                object
# First Posted                   object
# Locations                      object
# Study Documents                object
# dtype: object

# %% [markdown]
# 'Start Date', 'Primary Completion Date', 'Completion Date' and 'First Posted' all appear as objects.
# These will need to be converted to datetime.

# %% [markdown]
# ## 5. Memory Usage

# %%
df.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530028 entries, 0 to 530027
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   NCT Number                  530028 non-null  object
#  1   Study Title                 530028 non-null  object
#  2   Study URL                   530028 non-null  object
#  3   Study Status                530028 non-null  object
#  4   Conditions                  530025 non-null  object
#  5   Interventions               477836 non-null  object
#  6   Primary Outcome Measures    516558 non-null  object
#  7   Secondary Outcome Measures  387051 non-null  object
#  8   Sponsor                     530028 non-null  object
#  9   Collaborators               172143 non-null  object
#  10  Age                         530028 non-null  object
#  11  Phases                      204238 non-null  object
#  12  Enrollment                  526154 non-null  float64
#  13  Funder Type                 530028 non-null  object
#  14  Study Type                  530028 non-null  object
#  15  Study Design                530028 non-null  object
#  16  Start Date                  530028 non-null  object
#  17  Primary Completion Date     513022 non-null  object
#  18  Completion Date             517679 non-null  object
#  19  First Posted                530028 non-null  object
#  20  Locations                   486954 non-null  object
#  21  Study Documents             47926 non-null   object
# dtypes: float64(1), object(21)
# memory usage: 1.9 GB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 6. Missingness Overview

# %%
df.isna().mean().sort_values(ascending=False)
# Out:
# Study Documents               0.909578
# Collaborators                 0.675219
# Phases                        0.614666
# Secondary Outcome Measures    0.269754
# Interventions                 0.098470
# Locations                     0.081267
# Primary Completion Date       0.032085
# Primary Outcome Measures      0.025414
# Completion Date               0.023299
# Enrollment                    0.007309
# Conditions                    0.000006
# Study Status                  0.000000
# NCT Number                    0.000000
# Study Title                   0.000000
# Study URL                     0.000000
# Funder Type                   0.000000
# Sponsor                       0.000000
# Age                           0.000000
# Start Date                    0.000000
# Study Design                  0.000000
# Study Type                    0.000000
# First Posted                  0.000000
# dtype: float64

# %% [markdown]
# The above output shows the fraction of rows that are missing in each column. 'Study Documents' is mostly null values, and will be removed. Remaining columns will be analyzed and handled for missing values on a case-by-case basis.

# %% [markdown]
# ## 7. DataFrame Sample

# %%
df.sample(7)
# Out:
#          NCT Number                                        Study Title  \
# 80122   NCT06819995  Accuracy of Static Guided Implant Surgery: 3D-...
# 407089  NCT01975610  Efficacy and Safety Study of CC-292 Versus Pla...
# 529232  NCT04584060  Conventional VS Enhanced Recovery After Surger...
# 438381  NCT04735835  Personalized Responses to Dietary Composition ...
# 64400   NCT01400672  Imiquimod/Brain Tumor Initiating Cell (BTIC) V...
# 33386   NCT06841458  Six-Month Single-Blind, Placebo-Controlled Stu...
# 267340  NCT01907191  Ultrasound Guided Local Infiltration Analgesia...
#
#                                            Study URL Study Status  \
# 80122   https://clinicaltrials.gov/study/NCT06819995   RECRUITING
# 407089  https://clinicaltrials.gov/study/NCT01975610    COMPLETED
# 529232  https://clinicaltrials.gov/study/NCT04584060      UNKNOWN
# 438381  https://clinicaltrials.gov/study/NCT04735835   RECRUITING
# 64400   https://clinicaltrials.gov/study/NCT01400672   TERMINATED
# 33386   https://clinicaltrials.gov/study/NCT06841458   RECRUITING
# 267340  https://clinicaltrials.gov/study/NCT01907191   TERMINATED
#
#                                                Conditions  \
# 80122              Dental Implant|Guided Surgery Accuracy
# 407089                               Rheumatoid Arthritis
# 529232  Patient Presented With Acute Abdomen|Patient U...
# 438381  Diabetes|Heart Diseases|Diet Habit|Diet Modifi...
# 64400                    Diffuse Intrinsic Pontine Glioma
# 33386                               Androgenetic Alopecia
# 267340                                       Hip Injuries
#
#                                             Interventions  \
# 80122   PROCEDURE: Static guided implant placement wit...
# 407089                         DRUG: CC-292|DRUG: Placebo
# 529232  COMBINATION_PRODUCT: ERAS protocols|COMBINATIO...
# 438381                        OTHER: Dietary Intervention
# 64400   BIOLOGICAL: Tumor Lysate Vaccine|DRUG: Imiquim...
# 33386                              OTHER: Oral Supplement
# 267340      DRUG: liposomal bupivacaine|DRUG: Bupivacaine
#
#                                  Primary Outcome Measures  \
# 80122   Angular deviation, The discrepancy between the...
# 407089  American College of Rheumatology Criteria for ...
# 529232  Length of hospital stay, In days, Up to one month
# 438381  Glucose, Measurement of blood glucose by conti...
# 64400   Dose-limiting toxicity, Determined as Grade 3 ...
# 33386   Objective Evaluation of Hair Health Benefits A...
# 267340  Opioid Consumption (Mean Number of 5mg Oxycont...
#
#                                Secondary Outcome Measures  \
# 80122   Probing Depth (PD), This measurement will be p...
# 407089  Number of participants with adverse events, Sa...
# 529232  Time to ambulation, in hours, Up to one month|...
# 438381  Dietary assessment, Weighed food log, 6-14 day...
# 64400   Time to Tumor Progression, Imaging will includ...
# 33386   Subjective evaluation questionnaire, Consumer ...
# 267340  Pain Scores, Analysis of pain scores (at rest ...
#
#                                                Sponsor  \
# 80122                Universidad Complutense de Madrid
# 407089                                         Celgene
# 529232                               Assiut University
# 438381                              Zoe Global Limited
# 64400   Masonic Cancer Center, University of Minnesota
# 33386          Industrial Farmacéutica Cantabria, S.A.
# 267340                   Trinity Health Of New England
#
#                                             Collaborators  \
# 80122                             Klockner Implant System
# 407089                                                NaN
# 529232                                                NaN
# 438381  Massachusetts General Hospital|Stanford Univer...
# 64400                                                 NaN
# 33386                                                 NaN
# 267340                                                NaN
#
#                               Age  Phases  Enrollment Funder Type  \
# 80122          ADULT, OLDER_ADULT     NaN        48.0       OTHER
# 407089         ADULT, OLDER_ADULT  PHASE2        47.0    INDUSTRY
# 529232         ADULT, OLDER_ADULT     NaN        60.0       OTHER
# 438381         ADULT, OLDER_ADULT     NaN    250000.0       OTHER
# 64400   CHILD, ADULT, OLDER_ADULT  PHASE1         8.0       OTHER
# 33386                       ADULT     NaN        45.0    INDUSTRY
# 267340         ADULT, OLDER_ADULT     NaN        23.0       OTHER
#
#             Study Type                                       Study Design  \
# 80122   INTERVENTIONAL  Allocation: RANDOMIZED|Intervention Model: PAR...
# 407089  INTERVENTIONAL  Allocation: RANDOMIZED|Intervention Model: PAR...
# 529232   OBSERVATIONAL          Observational Model: |Time Perspective: p
# 438381  INTERVENTIONAL  Allocation: NA|Intervention Model: SINGLE_GROU...
# 64400   INTERVENTIONAL  Allocation: NA|Intervention Model: SINGLE_GROU...
# 33386   INTERVENTIONAL  Allocation: RANDOMIZED|Intervention Model: PAR...
# 267340  INTERVENTIONAL  Allocation: RANDOMIZED|Intervention Model: PAR...
#
#         Start Date Primary Completion Date Completion Date First Posted  \
# 80122   2025-02-15              2026-12-31      2026-12-31   2025-02-11
# 407089     2013-10                 2016-01         2016-02   2013-11-04
# 529232  2020-12-01              2021-11-30      2022-02-28   2020-10-12
# 438381  2020-07-20              2030-01-01      2030-01-01   2021-02-03
# 64400   2012-07-17              2016-03-07      2018-10-08   2011-07-22
# 33386   2024-10-07              2025-06-01      2025-06-01   2025-02-24
# 267340     2013-07              2019-01-30      2019-01-30   2013-07-24
#
#                                                 Locations  \
# 80122   Facultad de Odontología, Universidad Compluten...
# 407089  Achieve Clinical Research LLC, Birmingham, Ala...
# 529232                                                NaN
# 438381  Zoe US Inc., Needham, Massachusetts, 02494, Un...
# 64400   Masonic Cancer Center, University of Minnesota...
# 33386   DermaClaim, Valencia, Valencia, 46020, Spain|D...
# 267340  Saint Francis Hospital and Medical Center, Har...
#
#                                           Study Documents
# 80122                                                 NaN
# 407089                                                NaN
# 529232                                                NaN
# 438381                                                NaN
# 64400                                                 NaN
# 33386                                                 NaN
# 267340  Study Protocol and Statistical Analysis Plan, ...
